# %%
import geopandas as gpd
import pandas as pd

# %%
taxonomy= gpd.read_file("../data/Taxonomy_List.csv")

# %%
taxonomy
# Out:
#     MEDICARE SPECIALTY CODE MEDICARE PROVIDER/SUPPLIER TYPE DESCRIPTION  \
# 0                         1                  Physician/General Practice
# 1                         2                   Physician/General Surgery
# 2                         2                   Physician/General Surgery
# 3                         2                   Physician/General Surgery
# 4                         2                   Physician/General Surgery
# ..                      ...                                         ...
# 550                      D4           Undersea and Hyperbaric Medicine
# 551                      D5                   Opioid Treatment Program
# 552                      D6              Home Infusion Therapy Services
# 553                      D7           Micrographic Dermatologic Surgery
# 554                      D8             Adult Congenital Heart Disease
#
#     PROVIDER TAXONOMY CODE  \
# 0               208D00000X
# 1               208600000X
# ...

# %%
gpd.read_file("../data/States_shapefile.zip")
# Out:
#     FID          Program State_Code            State_Name Flowing_St  FID_1  \
# 0     1  PERMIT TRACKING         AL               ALABAMA          F    919
# 1     2              NaN         AK                ALASKA          N    920
# 2     3          AZURITE         AZ               ARIZONA          F    921
# 3     4              PDS         AR              ARKANSAS          F    922
# 4     5              NaN         CA            CALIFORNIA          N    923
# 5     6           ECOMAP         CO              COLORADO          F    924
# 6     7             SIMS         CT           CONNECTICUT          F    925
# 7     8              NaN         DE              DELAWARE          P    926
# 8     9              NaN         DC  DISTRICT OF COLUMBIA          P    927
# 9    10              NaN         FL               FLORIDA          P    928
# 10   11              NaN         GA               GEORGIA          N    929
# ...

# %%
gpd.read_file("../data/USA_Counties_(Generalized).zip")
# Out:
#        FID  OBJECTID             NAME    STATE_NAME STATE_FIPS CNTY_FIPS  \
# 0        1         1   Aleutians East        Alaska         02       013
# 1        2      1201           Traill  North Dakota         38       097
# 2        3      1202            Walsh  North Dakota         38       099
# 3        4         2   Aleutians West        Alaska         02       016
# 4        5      1203             Ward  North Dakota         38       101
# ...    ...       ...              ...           ...        ...       ...
# 3137  3138      2796          Harford      Maryland         24       025
# 3138  3139      2797           Howard      Maryland         24       027
# 3139  3140      2798             Kent      Maryland         24       029
# 3140  3141      2799       Montgomery      Maryland         24       031
# 3141  3142      2800  Prince George's      Maryland         24       033
#
#        FIPS  POPULATION  POP_SQMI  POP2010  ...  AVE_SIZE12  CROP_ACR12  \
# ...

# %%
zips= gpd.read_file("/srv/data/my_shared_data_folder/pb-data/zcta.gpkg")

# %%
zips
# Out:
#       ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  AWATER10  \
# 0         96799   96799        B5   G6350          S  197672934   1164505
# 1         96770   96770        B5   G6350          S  177285639  33377439
# 2         96769   96769        B5   G6350          S  193434451  44940998
# 3         96752   96752        B5   G6350          S   10418464   1877589
# 4         96796   96796        B5   G6350          S  119532951  11429247
# ...         ...     ...       ...     ...        ...        ...       ...
# 33139     96921   96921        B5   G6350          S     469602         0
# 33140     96929   96929        B5   G6350          S  171450561         0
# 33141     96951   96951        B5   G6350          S   85096798     19201
# 33142     96952   96952        B5   G6350          S  101224487    727567
# 33143     96950   96950        B5   G6350          S  118890997    185857
#
#         INTPTLAT10    INTPTLON10 STATEFP  TypeI  Geo_FIPS Geo_QName  \
# ...

# %%
states=gpd.read_file("/srv/data/my_shared_data_folder/pb-data/states.gpkg")

# %%
states
# Out:
#    REGION DIVISION Geo_FIPS   STATENS GEOID STUSPS  \
# 0       9        0       60  01802701    60     AS
# 1       4        9       15  01779782    15     HI
# 2       4        8       04  01779777    04     AZ
# 3       4        8       35  00897535    35     NM
# 4       3        7       48  01779801    48     TX
# 5       3        7       40  01102857    40     OK
# 6       4        9       06  01779778    06     CA
# 7       4        8       32  01779793    32     NV
# 8       4        8       49  01455989    49     UT
# 9       4        9       41  01155107    41     OR
# 10      4        9       53  01779804    53     WA
# 11      4        8       16  01779783    16     ID
# 12      4        8       30  00767982    30     MT
# 13      4        8       08  01779779    08     CO
# 14      2        4       31  01779792    31     NE
# 15      2        4       20  00481813    20     KS
# 16      4        8       56  01779807    56     WY
# ...

# %%
county=gpd.read_file("/srv/data/my_shared_data_folder/pb-data/county.gpkg")

# %%
county
# Out:
#       Remaining STATEFP COUNTYFP  COUNTYNS  GEOID              NAME  \
# 0      0.157025      60      010  01805240  60010           Eastern
# 1      0.269258      60      050  01805241  60050           Western
# 2      0.110428      60      020  01805242  60020            Manu'a
# 3      0.023642      60      040  01805244  60040     Swains Island
# 4      0.000557      60      030  01805243  60030       Rose Island
# ...         ...     ...      ...       ...    ...               ...
# 3228   0.368382      66      010  01802705  66010              Guam
# 3229   0.136338      69      100  01805246  69100              Rota
# 3230   0.146162      69      120  01805248  69120            Tinian
# 3231   0.051640      69      085  01805245  69085  Northern Islands
# 3232   0.182711      69      110  01805247  69110            Saipan
#
#                            NAMELSAD LSAD CLASSFP  MTFCC  ... FUNCSTAT  \
# 0                  Eastern District   07      H1  G4020  ...        A
# ...

# %%
tracts=gpd.read_file("/srv/data/my_shared_data_folder/pb-data/tracts.gpkg")

# %%
tracts
# Out:
#       STATEFP COUNTYFP Geo_FIPS        GEOID     NAME             Geo_QNAME  \
# 0          60      050   951300  60050951300     9513     Census Tract 9513
# 1          60      050   951203  60050951203  9512.03  Census Tract 9512.03
# 2          60      050   951201  60050951201  9512.01  Census Tract 9512.01
# 3          60      050   951600  60050951600     9516     Census Tract 9516
# 4          60      050   951100  60050951100     9511     Census Tract 9511
# ...       ...      ...      ...          ...      ...                   ...
# 73806      69      110   000200  69110000200        2        Census Tract 2
# 73807      69      110   000300  69110000300        3        Census Tract 3
# 73808      69      110   001700  69110001700       17       Census Tract 17
# 73809      69      110   000100  69110000100        1        Census Tract 1
# 73810      69      085   950100  69085950100     9501     Census Tract 9501
#
# ...

# %%
providers=gpd.read_file("/srv/data/my_shared_data_folder/pb-data/vision_providers_geocoded.gpkg")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 providers=gpd.read_file("/srv/data/my_shared_data_folder/pb-data/vision_providers_geocoded.gpkg")
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/io/file.py:281, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     278     else:
#     279         path_or_bytes = filename
# --> 281     return _read_file_fiona(
#     282         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     283     )
#     285 else:
#     286     raise ValueError(f"unknown engine '{engine}'")
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/io/file.py:379, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     375     df = pd.DataFrame(
#     376         [record["properties"] for record in f_filt], columns=columns
#     377     )
# ...

# %%
providers

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(16, 16))
states.plot(ax=ax, color='#ffffff', edgecolor='#6a6a6a', linewidth=2)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10,10))
county.plot(ax=ax, color='g', edgecolor='w', linewidth=0.1)

ax.set_xlim(-190, -60)
ax.set_ylim(15,75)
# Out:
# (15.0, 75.0)

# %%
fig, ax = plt.subplots(figsize=(10,10))
tracts.plot(ax=ax, color='g', edgecolor='w', linewidth=0.1)

ax.set_xlim(-190, -60)
ax.set_ylim(15,75)
# Out:
# (15.0, 75.0)
